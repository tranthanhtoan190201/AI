# %%
import numpy as np
#doc dia chi hinh anh
import os
#xu ly ve hinh anh
from PIL import Image

# %%
#khai bien doc dia chi
train_data ='drive/MyDrive/baitapvenha2/hinh_2/train'
test_data='drive/MyDrive/baitapvenha2/hinh_2/test'
validation_data='drive/MyDrive/baitapvenha2/hinh_2/validation'

# %%
listdata_train=[]
listdata_test=[]
listdata_validation=[]
dict={'dung':[0],'tai':[1],'toan':[2]}

# %%
def Getdata(dirdata,lstdata):
#doc hinh anh trong tap du lieu
  for whatever in os.listdir(dirdata):
      whatever_path = os.path.join(dirdata,whatever)
      lst_filename_path=[]
      for filename in os.listdir(whatever_path):
        filename_path=os.path.join(whatever_path,filename)
        label=filename_path.split('/')[5]
        img = np.array(Image.open(filename_path))
        lst_filename_path.append((img,dict[label]))
      lstdata.extend(lst_filename_path)
  for i in range(3):
      np.random.shuffle(lstdata)
  return lstdata

# %%
listdata_train=Getdata(train_data,listdata_train)
listdata_test=Getdata(test_data,listdata_test)
listdata_validation=Getdata(validation_data,listdata_validation)

# %%
x_train=np.array([x[0] for _ ,x in enumerate(listdata_train)])
y_train=np.array([y[1] for _ ,y in enumerate(listdata_train)])
y_train.shape
# Out:
# (128, 1)

# %%
x_test=np.array([x[0] for _ ,x in enumerate(listdata_test)])
y_test=np.array([y[1] for _ ,y in enumerate(listdata_test)])

# %%
x_validation=np.array([x[0] for _ ,x in enumerate(listdata_validation)])
y_validation=np.array([y[1] for _ ,y in enumerate(listdata_validation)])
x_validation.shape
# Out:
# (18, 150, 150, 3)

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array

# %%
yname=y_train.flatten()

# %%
class_names=['dung','tai','toan']
x_pre=x_test
y_pre=y_test
y_pre
# Out:
# array([[0],
#        [2],
#        [1],
#        [1],
#        [2],
#        [2],
#        [1],
#        [1],
#        [2],
#        [2],
#        [0],
#        [1],
#        [1],
#        [0],
#        [1],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [1],
#        [0],
#        [1],
#        [2],
#        [0],
#        [0],
#        [1],
#        [0],
#        [2],
#        [0]])

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i], cmap='binary')
    plt.xlabel(class_names[yname[i]])
plt.show()

# %%
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_validation=x_validation.astype('float32')
x_train/=255
x_test/=255
x_validation/=255
y_train=np_utils.to_categorical(y_train,3)
y_test= np_utils.to_categorical(y_test,3)
y_validation= np_utils.to_categorical(y_validation,3)

# %%
model=Sequential()
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 150, 150, 64)      1792
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 128)       73856
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 256)       295168
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 256)       590080
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 256)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 82944)             0
#
#  dense_2 (Dense)             (None, 512)               42467840
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 43,614,787
# Trainable params: 43,614,787
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,epochs=100,batch_size=70,verbose=1, validation_data=(x_validation,y_validation), callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 447ms/step - loss: 78.0516 - accuracy: 0.3516 - val_loss: 24.5545 - val_accuracy: 0.3333
# Epoch 2/100
# 2/2 [==============================] - 1s 293ms/step - loss: 14.3123 - accuracy: 0.3359 - val_loss: 9.8515 - val_accuracy: 0.3333
# Epoch 3/100
# 2/2 [==============================] - 1s 296ms/step - loss: 6.4753 - accuracy: 0.3828 - val_loss: 1.3023 - val_accuracy: 0.3333
# Epoch 4/100
# 2/2 [==============================] - 1s 291ms/step - loss: 1.2574 - accuracy: 0.3125 - val_loss: 1.1627 - val_accuracy: 0.3333
# Epoch 5/100
# 2/2 [==============================] - 1s 290ms/step - loss: 1.0667 - accuracy: 0.3984 - val_loss: 1.0167 - val_accuracy: 1.0000
# Epoch 6/100
# 2/2 [==============================] - 1s 291ms/step - loss: 1.0064 - accuracy: 0.5469 - val_loss: 0.9527 - val_accuracy: 0.7222
# Epoch 7/100
# 2/2 [==============================] - 1s 289ms/step - loss: 0.9115 - accuracy: 0.7578 - val_loss: 0.6478 - val_accuracy: 0.9444
# Epoch 8/100
# 2/2 [==============================] - 1s 295ms/step - loss: 0.6568 - accuracy: 0.7891 - val_loss: 0.2434 - val_accuracy: 1.0000
# Epoch 9/100
# 2/2 [==============================] - 1s 292ms/step - loss: 0.3772 - accuracy: 0.8281 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 10/100
# 2/2 [==============================] - 1s 289ms/step - loss: 0.3067 - accuracy: 0.8828 - val_loss: 0.1371 - val_accuracy: 1.0000
# Epoch 11/100
# 2/2 [==============================] - 1s 295ms/step - loss: 0.1303 - accuracy: 0.9766 - val_loss: 0.0584 - val_accuracy: 1.0000
# Epoch 12/100
# 2/2 [==============================] - 1s 325ms/step - loss: 0.0698 - accuracy: 0.9844 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 13/100
# 2/2 [==============================] - 1s 354ms/step - loss: 0.0305 - accuracy: 0.9922 - val_loss: 8.3368e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 2/2 [==============================] - 1s 299ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 7.7597e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 2/2 [==============================] - 1s 367ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4054e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 2/2 [==============================] - 1s 293ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 5.3905e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 2/2 [==============================] - 1s 296ms/step - loss: 7.5835e-04 - accuracy: 1.0000 - val_loss: 9.0549e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 2/2 [==============================] - 1s 295ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.4311e-05 - val_accuracy: 1.0000
# Epoch 19/100
# 2/2 [==============================] - 1s 323ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 5.7682e-06 - val_accuracy: 1.0000
# Epoch 20/100
# 2/2 [==============================] - 1s 294ms/step - loss: 1.8702e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 21/100
# 2/2 [==============================] - 1s 294ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 8.7031e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 2/2 [==============================] - 1s 291ms/step - loss: 6.1579e-04 - accuracy: 1.0000 - val_loss: 3.4865e-05 - val_accuracy: 1.0000
# Epoch 23/100
# 2/2 [==============================] - 1s 290ms/step - loss: 2.4433e-04 - accuracy: 1.0000 - val_loss: 4.3180e-06 - val_accuracy: 1.0000
# Epoch 24/100
# 2/2 [==============================] - 1s 291ms/step - loss: 5.4534e-04 - accuracy: 1.0000 - val_loss: 4.3445e-06 - val_accuracy: 1.0000
# Epoch 25/100
# 2/2 [==============================] - 1s 291ms/step - loss: 7.8801e-05 - accuracy: 1.0000 - val_loss: 6.9338e-06 - val_accuracy: 1.0000
# Epoch 26/100
# 2/2 [==============================] - 1s 297ms/step - loss: 5.0680e-05 - accuracy: 1.0000 - val_loss: 9.4569e-06 - val_accuracy: 1.0000
# Epoch 27/100
# 2/2 [==============================] - 1s 291ms/step - loss: 8.3493e-05 - accuracy: 1.0000 - val_loss: 1.1371e-05 - val_accuracy: 1.0000
# Epoch 28/100
# 2/2 [==============================] - 1s 295ms/step - loss: 1.6211e-04 - accuracy: 1.0000 - val_loss: 1.1675e-05 - val_accuracy: 1.0000
# Epoch 29/100
# 2/2 [==============================] - 1s 321ms/step - loss: 4.8252e-05 - accuracy: 1.0000 - val_loss: 1.1397e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 2/2 [==============================] - 1s 290ms/step - loss: 8.1356e-06 - accuracy: 1.0000 - val_loss: 1.0848e-05 - val_accuracy: 1.0000
# Epoch 31/100
# 2/2 [==============================] - 1s 296ms/step - loss: 1.3039e-05 - accuracy: 1.0000 - val_loss: 1.0252e-05 - val_accuracy: 1.0000
# Epoch 32/100
# 2/2 [==============================] - 1s 360ms/step - loss: 2.9025e-05 - accuracy: 1.0000 - val_loss: 9.5232e-06 - val_accuracy: 1.0000
# Epoch 33/100
# 2/2 [==============================] - 1s 315ms/step - loss: 2.2062e-05 - accuracy: 1.0000 - val_loss: 8.6557e-06 - val_accuracy: 1.0000
# Epoch 34/100
# 2/2 [==============================] - 1s 308ms/step - loss: 1.9397e-05 - accuracy: 1.0000 - val_loss: 7.7947e-06 - val_accuracy: 1.0000
# Epoch 35/100
# 2/2 [==============================] - 1s 362ms/step - loss: 1.3079e-05 - accuracy: 1.0000 - val_loss: 6.9934e-06 - val_accuracy: 1.0000
# Epoch 36/100
# 2/2 [==============================] - 1s 293ms/step - loss: 1.1483e-05 - accuracy: 1.0000 - val_loss: 6.2848e-06 - val_accuracy: 1.0000
# Epoch 37/100
# 2/2 [==============================] - 1s 298ms/step - loss: 7.0912e-05 - accuracy: 1.0000 - val_loss: 5.6954e-06 - val_accuracy: 1.0000
# Epoch 38/100
# 2/2 [==============================] - 1s 293ms/step - loss: 7.3849e-06 - accuracy: 1.0000 - val_loss: 5.1524e-06 - val_accuracy: 1.0000
# Epoch 39/100
# 2/2 [==============================] - 1s 293ms/step - loss: 6.5036e-05 - accuracy: 1.0000 - val_loss: 5.1656e-06 - val_accuracy: 1.0000
# Epoch 40/100
# 2/2 [==============================] - 1s 293ms/step - loss: 4.8910e-06 - accuracy: 1.0000 - val_loss: 5.6027e-06 - val_accuracy: 1.0000
# Epoch 41/100
# 2/2 [==============================] - 1s 290ms/step - loss: 4.4171e-06 - accuracy: 1.0000 - val_loss: 5.9471e-06 - val_accuracy: 1.0000
# Epoch 42/100
# 2/2 [==============================] - 1s 325ms/step - loss: 7.6271e-06 - accuracy: 1.0000 - val_loss: 6.1126e-06 - val_accuracy: 1.0000
# Epoch 43/100
# 2/2 [==============================] - 1s 296ms/step - loss: 1.6410e-06 - accuracy: 1.0000 - val_loss: 6.2385e-06 - val_accuracy: 1.0000

# %%
model.save("Nhan_dien_nguoi.h5")
model_nhandien=load_model('Nhan_dien_nguoi.h5')

# %%
Score=model_nhandien.evaluate(x_test,y_test,verbose=0)
print('Test loss',Score[0])
print('Test accuary', Score[1])
# Out:
# Test loss 3.512654757287237e-06
# Test accuary 1.0

# %%
plt.figure(figsize=(20, 20))
for i in range(30):
    plt.subplot(10, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_pre[i], cmap='binary')
    plt.title("Model dự đoán là: " + str(class_names[np.argmax(model_nhandien.predict(x_pre[i].reshape((-1,150,150,3,))))]))
plt.show()
